# %% [markdown]
# # Contexte
# L'accès à l'eau potable est essentiel à la santé, un droit humain fondamental et une composante d'une politique efficace de protection de la santé. Il s'agit d'une question de santé et de développement importante au niveau national, régional et local. Dans certaines régions, il a été démontré que les investissements dans l'approvisionnement en eau et l'assainissement peuvent apporter un bénéfice économique net, puisque la réduction des effets néfastes sur la santé et des coûts des soins de santé est supérieure aux coûts des interventions.
#
# ## Contenu
# Le fichier water_potability.csv contient des mesures de la qualité de l'eau pour 3276 masses d'eau différentes.
#
# 1. **Valeur du pH** :
# Le PH est un paramètre important pour évaluer l'équilibre acide-base de l'eau. C'est également l'indicateur de l'état acide ou alcalin de l'eau. L'OMS a recommandé une limite maximale admissible du pH de 6,5 à 8,5. L'enquête actuelle a révélé des valeurs de 6,52 à 6,83, ce qui est conforme aux normes de l'OMS.
#
# 2. **La dureté** :
# La dureté est principalement causée par les sels de calcium et de magnésium. Ces sels sont dissous à partir de dépôts géologiques que l'eau traverse. La durée pendant laquelle l'eau est en contact avec des matériaux produisant de la dureté aide à déterminer la quantité de dureté présente dans l'eau brute. La dureté a été définie à l'origine comme la capacité de l'eau à précipiter le savon causé par le calcium et le magnésium.
#
# 3. **Solides (Total des solides dissous - TDS)** :
# L'eau a la capacité de dissoudre un large éventail de minéraux ou de sels inorganiques et certains organiques tels que le potassium, le calcium, le sodium, les bicarbonates, les chlorures, le magnésium, les sulfates, etc. Ces minéraux produisent un goût indésirable et une couleur diluée dans l'apparence de l'eau. Il s'agit d'un paramètre important pour l'utilisation de l'eau. L'eau avec une valeur TDS élevée indique que l'eau est hautement minéralisée. La limite souhaitable pour le TDS est de 500 mg/l et la limite maximale est de 1000 mg/l, ce qui est prescrit pour la consommation.
#
# 4. **Chloramines** :
# Le chlore et la chloramine sont les principaux désinfectants utilisés dans les systèmes d'eau publics. Les chloramines se forment le plus souvent lorsque de l'ammoniac est ajouté au chlore pour traiter l'eau potable. Des niveaux de chlore allant jusqu'à 4 milligrammes par litre (mg/L ou 4 parties par million (ppm)) sont considérés comme sûrs dans l'eau potable.
#
# 5. **Sulfate** :
# Les sulfates sont des substances naturelles que l'on trouve dans les minéraux, le sol et les roches. Ils sont présents dans l'air ambiant, les eaux souterraines, les plantes et les aliments. La principale utilisation commerciale du sulfate est dans l'industrie chimique. La concentration de sulfate dans l'eau de mer est d'environ 2 700 milligrammes par litre (mg/L). Elle varie de 3 à 30 mg/L dans la plupart des réserves d'eau douce, bien que l'on trouve des concentrations beaucoup plus élevées (1000 mg/L) dans certains endroits géographiques.
#
# 6. **Conductivité** :
# L'eau pure n'est pas un bon conducteur de courant électrique ; c'est plutôt un bon isolant. L'augmentation de la concentration en ions accroît la conductivité électrique de l'eau. En général, la quantité de solides dissous dans l'eau détermine la conductivité électrique. La conductivité électrique (CE) mesure en fait le processus ionique d'une solution qui lui permet de transmettre le courant. Selon les normes de l'OMS, la valeur de la CE ne doit pas dépasser 400 μS/cm.
#
# 7. **Carbone_organique** :
# Le carbone organique total (COT) dans les eaux de source provient de la matière organique naturelle en décomposition (NOM) ainsi que de sources synthétiques. Le COT est une mesure de la quantité totale de carbone dans les composés organiques de l'eau pure. Selon l'US EPA, le COT doit être inférieur à 2 mg/l dans l'eau traitée ou potable, et inférieur à 4 mg/l dans l'eau de source utilisée pour le traitement.
#
# 8. **Trihalométhanes** :
# Les THM sont des produits chimiques qui peuvent être trouvés dans l'eau traitée au chlore. La concentration de THM dans l'eau potable varie en fonction du niveau de matière organique dans l'eau, de la quantité de chlore nécessaire pour traiter l'eau et de la température de l'eau qui est traitée. Une concentration de THM allant jusqu'à 80 ppm est considérée comme sûre dans l'eau potable.
#
# 9. **Turbidité** :
# La turbidité de l'eau dépend de la quantité de matières solides présentes à l'état de suspension. C'est une mesure des propriétés d'émission de lumière de l'eau et le test est utilisé pour indiquer la qualité du rejet des déchets en ce qui concerne les matières colloïdales. La valeur moyenne de turbidité obtenue pour le Wondo Genet Campus (0.98 NTU) est inférieure à la valeur recommandée par l'OMS de 5.00 NTU.
#
# 10. **Potabilité** :
# Indique si l'eau est propre à la consommation humaine, où 1 signifie Potable et 0 signifie Non potable.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_row', 111)
pd.set_option('display.max_column', 111)

# %% [markdown]
# # importation du dataset

# %%
data = pd.read_csv('water_potability.csv')
df = data.copy()

# %%
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %% [markdown]
# ## Analyse de la forme des données

# %%
df.shape
# Out:
# (3276, 10)

# %%
df.dtypes.value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df.isnull().mean(axis=0).sort_values()*100
# Out:
# Hardness            0.000000
# Solids              0.000000
# Chloramines         0.000000
# Conductivity        0.000000
# Organic_carbon      0.000000
# Turbidity           0.000000
# Potability          0.000000
# Trihalomethanes     4.945055
# ph                 14.987790
# Sulfate            23.840049
# dtype: float64

# %% [markdown]
# ## Analyse du Fond
# ### 1. Visulation initiale - Elimination des colonnes inutiles

# %% [markdown]
# ### Examen de la colonne target

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %%
df['Potability'].value_counts(normalize=True)
# Out:
# 0    0.60989
# 1    0.39011
# Name: Potability, dtype: float64

# %% [markdown]
# on a 60.9% de l'eau non potable et 39% de l'eau potable

# %% [markdown]
# ### histogrames des variables continues
#
# on voit dans les histogrames ci-dessous la distribution des valeurs continues

# %%
for col in df.select_dtypes('float'):
    plt.figure()
    sns.distplot(df[col])

# %% [markdown]
# ## Relation Target / Variables
# ### Création de sous-ensembles positifs et négatifs

# %%
positive_df = df[df['Potability'] == 1]
negative_df = df[df['Potability'] == 0]

# %%
for col in df.select_dtypes('float'):
    plt.figure()
    sns.distplot(positive_df[col], label='positive')
    sns.distplot(negative_df[col], label='negative')
    plt.legend()

# %% [markdown]
# #### remarque
# on constate dans la plupart des histogrammes que la distribution des deux sous ensembles est presque la même, et ceci peut être dû à la normalisation des données

# %% [markdown]
# - **pH** est entre 6,5 et 9.
# pour que l'eau soit potable, il faut que son PH soit compris entre 6.5 et 9

# %%
ph_non_conform = df[(df['ph'] < 6.5) | (df['ph'] > 9 )]

# %%
print("pourcentage de l'eau non potable :" , ph_non_conform['Potability'].value_counts(normalize=True)[0]*100 ,"%")
print("pourcentage de l'eau potable     :" , ph_non_conform['Potability'].value_counts(normalize=True)[1]*100 ,"%")
# Out:
# pourcentage de l'eau non potable : 63.921568627450974 %
# pourcentage de l'eau potable     : 36.07843137254902 %

# %%
#ph conforme

print("pourcentage de l'eau non potable :" , df[~((df['ph'] < 6.5) | (df['ph'] > 9 ))]['Potability'].value_counts(normalize=True)[0]*100 ,"%")
print("pourcentage de l'eau potable     :" , df[~((df['ph'] < 6.5) | (df['ph'] > 9 ))]['Potability'].value_counts(normalize=True)[1]*100 ,"%")
# Out:
# pourcentage de l'eau non potable : 59.12043978010995 %
# pourcentage de l'eau potable     : 40.87956021989005 %

# %%
X =df.drop('Potability',axis=1,inplace=False)
y = df['Potability']
df.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability'],
#       dtype='object')

# %% [markdown]
# # imputation des valeurs manquantes
#
# j'utilise 'KNNImputer' baser sur l'algoritme k-nearest neighbors

# %%
from sklearn.impute import KNNImputer

# %%
imputer = KNNImputer(n_neighbors= 50)
X = imputer.fit_transform(X)

# %%
X = pd.DataFrame(X,columns=['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
       'Organic_carbon', 'Trihalomethanes', 'Turbidity'])

# %%
plt.figure(figsize=(20,15))
plt.plot(X)
plt.legend(X.columns)

# %%
df['Solids'].var()
# Out:
# 76887834.36189844

# %% [markdown]
# ### remarque
#
# la variation  du Solides (Total des solides dissous - TDS) est tres grand

# %%
plt.figure(figsize=(20,15))
plt.plot(X.drop(columns=["Solids"]))
plt.legend(X.drop(columns=["Solids"]).columns)

# %%
sns.pairplot(pd.concat([X,y],axis=1),hue='Potability')

# %% [markdown]
# # test de Student
#
# pour avoir un test efficace on doit avoir deux sous groupes egaux

# %%
from scipy.stats import ttest_ind

# %%
negative_df_1=negative_df.sample(positive_df.shape[0])

# %%
def t_test(col):
    alpha = 0.02
    stat, p = ttest_ind(negative_df_1[col],positive_df[col])
    if p < alpha:
        return 'H0 Rejetée'
    else :
        return 0

# %%
for col in negative_df.columns[:-1]:
    print(f'{col :-<50} {t_test(col)}')
# Out:
# ph------------------------------------------------ 0
# Hardness------------------------------------------ 0
# Solids-------------------------------------------- 0
# Chloramines--------------------------------------- 0
# Sulfate------------------------------------------- 0
# Conductivity-------------------------------------- 0
# Organic_carbon------------------------------------ 0
# Trihalomethanes----------------------------------- 0
# Turbidity----------------------------------------- 0

# %% [markdown]
# tous les valuers sont significativement au point de vue statistique.

# %% [markdown]
# # Feature Selection
#
# La sélection des caractéristiques est une technique par laquelle nous choisissons les caractéristiques de nos données qui contribuent le plus à la variable cible. En d'autres termes, nous choisissons les meilleurs prédicteurs pour la variable cible.
#
# Les classes du module sklearn.feature_selection peuvent être utilisées pour la sélection de caractéristiques/la réduction de la dimensionnalité sur des ensembles d'échantillons, soit pour améliorer les scores de précision des estimateurs, soit pour augmenter leurs performances sur des ensembles de données à très haute dimension.
#
# Avantage :
#
# - Réduit l'overfitting :
# Moins de données redondantes signifie moins de possibilité de prendre des décisions basées sur des données redondantes/bruit.
# - Améliore la précision :
# Moins de données trompeuses signifie une amélioration de la précision de la modélisation.
# Réduction du temps de formation : Moins de données signifie que les algorithmes s'entraînent plus rapidement.
#
# ## Recursive feature Elimination
#
# **Recursive feature elimination** (RFE) est une méthode de sélection des caractéristiques qui ajuste un modèle et élimine la ou les caractéristiques les plus faibles jusqu'à ce que le nombre spécifié de caractéristiques soit atteint. ... L'élimination récursive des caractéristiques requiert un nombre précis de caractéristiques à conserver, mais il est souvent impossible de savoir à l'avance combien de caractéristiques sont valides.

# %%
from sklearn.feature_selection import RFECV
from sklearn.linear_model import SGDClassifier

# %%
selector = RFECV(SGDClassifier(random_state=0), step=1, min_features_to_select=4, cv=15)
selector.fit(X, y)
print(selector.ranking_)
print(selector.grid_scores_)
# Out:
# [2 1 1 1 1 1 1 1 3]
# [0.52570623 0.55259799 0.52813316 0.58029548 0.52178096 0.53540977]

# %%
np.array(X.columns)[selector.get_support()]
# Out:
# array(['Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes'], dtype=object)

# %% [markdown]
# ## SelectKBest
# ### Test de khi-deux

# %%
from sklearn.feature_selection import SelectKBest, chi2, f_classif

# %%
selector = SelectKBest(chi2, k=4)
selector.fit(X, y)
selector.scores_
np.array(X.columns)[selector.get_support()]
# Out:
# array(['Hardness', 'Solids', 'Sulfate', 'Conductivity'], dtype=object)

# %%
selector = SelectKBest(f_classif, k=4)
selector.fit(X, y)
selector.scores_
np.array(X.columns)[selector.get_support()]
# Out:
# array(['Solids', 'Chloramines', 'Sulfate', 'Organic_carbon'], dtype=object)

# %% [markdown]
# je garde les colonnes:
#
#     -ph
#     -Solids
#     -Hardness
#     -Chloramines
#     -Organic_carbon
#     -Sulfate

# %%
X.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity'],
#       dtype='object')

# %%
X=X.drop(columns=["Conductivity",'Trihalomethanes','Turbidity'])

# %% [markdown]
# # modele

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier


pgrid={"splitter":["best","random"],
             "max_depth":range(2,20,1),
             "min_samples_leaf":range(1,15,1),
             "min_samples_split":range(2,20,1) 
            }
grid_search = GridSearchCV(DecisionTreeClassifier(), param_grid=pgrid, cv=5)
grid_search.fit(X_train, y_train)
grid_search.best_estimator_.score(X_test, y_test)
# Out:
# 0.6349353049907579

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_split=19, splitter='random')

# %%
from sklearn import tree

plt.figure(figsize=(12,12))
tree.plot_tree(grid_search.best_estimator_,rounded=True,filled=True)
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

param_grids = {"penalty" : ["l2", "l1", "elasticnet"],
              "alpha": np.linspace(0.00001,0.1, 20)}
grid = GridSearchCV(estimator = SGDClassifier(), param_grid=param_grids, cv=5)

grid.fit(X_train, y_train)
grid.best_estimator_.score(X_test, y_test)
# Out:
# 0.6284658040665434

# %%
grid.best_estimator_
# Out:
# SGDClassifier(alpha=0.005272631578947368)

# %%
from sklearn.pipeline import make_pipeline

clf = make_pipeline(StandardScaler(),SGDClassifier())
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
clf.score(X_test, y_test)
print('test score = %0.2f, train score = %0.2f' %(clf.score(X_test,y_test),clf.score(X_train,y_train)))
# Out:
# test score = 0.64, train score = 0.61

# %%
df.shape
# Out:
# (3276, 10)

# %% [markdown]
# #  TensorFlow

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout

# %%
model = Sequential()

# https://stats.stackexchange.com/questions/181/how-to-choose-the-number-of-hidden-layers-and-nodes-in-a-feedforward-neural-netw

model.add(Dense(units=10,activation='relu'))

model.add(Dense(units=10,activation='relu'))

model.add(Dense(units=5,activation='relu'))

model.add(Dense(units=1,activation='sigmoid'))

# For a binary classification problem
model.compile(loss='binary_crossentropy', optimizer='adam')

# %% [markdown]
# from tensorflow.keras.callbacks import EarlyStopping
# early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)

# %%
model.fit(x=X_train, 
          y=y_train, 
          epochs=200,
          validation_data=(X_test, y_test), verbose=1
          )

model_loss = pd.DataFrame(model.history.history)
model_loss.plot()
# Out:
# Epoch 1/200
# 69/69 [==============================] - 1s 6ms/step - loss: 0.6897 - val_loss: 0.6733
# Epoch 2/200
# 69/69 [==============================] - 0s 2ms/step - loss: 0.6731 - val_loss: 0.6622
# Epoch 3/200
# 69/69 [==============================] - 0s 2ms/step - loss: 0.6655 - val_loss: 0.6527
# Epoch 4/200
# 69/69 [==============================] - 0s 2ms/step - loss: 0.6526 - val_loss: 0.6443
# Epoch 5/200
# 69/69 [==============================] - 0s 3ms/step - loss: 0.6530 - val_loss: 0.6378
# Epoch 6/200
# 69/69 [==============================] - 0s 3ms/step - loss: 0.6350 - val_loss: 0.6325
# Epoch 7/200
# 69/69 [==============================] - 0s 2ms/step - loss: 0.6350 - val_loss: 0.6277
# Epoch 8/200
# 69/69 [==============================] - 0s 2ms/step - loss: 0.6276 - val_loss: 0.6237
# Epoch 9/200
# 69/69 [==============================] - 0s 2ms/step - loss: 0.6266 - val_loss: 0.6209
# Epoch 10/200
# ...
